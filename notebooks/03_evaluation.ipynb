# %% [markdown]
# (venv) C:\Users\hbish\Desktop\Shl Recommendation System>python src\evaluation\metrics.py
# Loading recommender system...
# Metadata columns: ['name', 'url', 'description', 'product_type', 'duration', 'remote_support', 'adaptive_support', 'test_type']
# ⚠ Warning: GOOGLE_API_KEY not set. LLM features disabled.
# ✓ Loaded 377 assessments
#
# ======================================================================
# EVALUATING ON TRAIN SET
# ======================================================================
#
# Generating predictions for 10 queries...
#   [1/10] Based on the JD below recommend me assessment for the Consul...
#   [2/10] Content Writer required, expert in English and SEO....
#   [3/10] Find me 1 hour long assesment for the below job at SHL
# Job D...
#   [4/10] I am hiring for Java developers who can also collaborate eff...
#   [5/10] I am looking for a COO for my company in China and I want to...
#   [6/10] I want to hire a Senior Data Analyst with 5 years of experie...
#   [7/10] I want to hire new graduates for a sales role in my company,...
#   [8/10] ICICI Bank Assistant Admin, Experience required 0-2 years, t...
#   [9/10] KEY RESPONSIBITILES:
#
# Manage the sound-scape of the station ...
#   [10/10] We're looking for a Marketing Manager who can drive Recro’s ...
#
# ======================================================================
# EVALUATION RESULTS
# ======================================================================
# Mean Recall@5: 0.1411
# Mean Recall@10: 0.1911
#
# ======================================================================
# PER-QUERY ANALYSIS
# ======================================================================
#
# Best performing queries:
#   Recall@10: 0.6000 - I am hiring for Java developers who can also collaborate eff...
#   Recall@10: 0.4000 - Content Writer required, expert in English and SEO....
#   Recall@10: 0.4000 - I want to hire a Senior Data Analyst with 5 years of experie...
#
# Worst performing queries:
#   Recall@10: 0.0000 - Find me 1 hour long assesment for the below job at SHL
# Job D...
#   Recall@10: 0.0000 - I am looking for a COO for my company in China and I want to...
#   Recall@10: 0.0000 - ICICI Bank Assistant Admin, Experience required 0-2 years, t...
#
# ======================================================================
# GENERATING TEST PREDICTIONS
# ======================================================================
#
# Generating predictions for 65 test queries...
#   [1/65] I am hiring for Java developers who can also collaborate eff...
#   [2/65] I am hiring for Java developers who can also collaborate eff...
#   [3/65] I am hiring for Java developers who can also collaborate eff...
#   [4/65] I am hiring for Java developers who can also collaborate eff...
#   [5/65] I am hiring for Java developers who can also collaborate eff...
#   [6/65] I want to hire new graduates for a sales role in my company,...
#   [7/65] I want to hire new graduates for a sales role in my company,...
#   [8/65] I want to hire new graduates for a sales role in my company,...
#   [9/65] I want to hire new graduates for a sales role in my company,...
#   [10/65] I want to hire new graduates for a sales role in my company,...
#   [11/65] I want to hire new graduates for a sales role in my company,...
#   [12/65] I want to hire new graduates for a sales role in my company,...
#   [13/65] I want to hire new graduates for a sales role in my company,...
#   [14/65] I want to hire new graduates for a sales role in my company,...
#   [15/65] I am looking for a COO for my company in China and I want to...
#   [16/65] I am looking for a COO for my company in China and I want to...
#   [17/65] I am looking for a COO for my company in China and I want to...
#   [18/65] I am looking for a COO for my company in China and I want to...
#   [19/65] I am looking for a COO for my company in China and I want to...
#   [20/65] I am looking for a COO for my company in China and I want to...
#   [21/65] KEY RESPONSIBITILES:
#
# Manage the sound-scape of the station ...
#   [22/65] KEY RESPONSIBITILES:
#
# Manage the sound-scape of the station ...
#   [23/65] KEY RESPONSIBITILES:
#
# Manage the sound-scape of the station ...
#   [24/65] KEY RESPONSIBITILES:
#
# Manage the sound-scape of the station ...
#   [25/65] KEY RESPONSIBITILES:
#
# Manage the sound-scape of the station ...
#   [26/65] Content Writer required, expert in English and SEO....
#   [27/65] Content Writer required, expert in English and SEO....
#   [28/65] Content Writer required, expert in English and SEO....
#   [29/65] Content Writer required, expert in English and SEO....
#   [30/65] Content Writer required, expert in English and SEO....
#   [31/65] Find me 1 hour long assesment for the below job at SHL
# Job D...
#   [32/65] Find me 1 hour long assesment for the below job at SHL
# Job D...
#   [33/65] Find me 1 hour long assesment for the below job at SHL
# Job D...
#   [34/65] Find me 1 hour long assesment for the below job at SHL
# Job D...
#   [35/65] Find me 1 hour long assesment for the below job at SHL
# Job D...
#   [36/65] Find me 1 hour long assesment for the below job at SHL
# Job D...
#   [37/65] Find me 1 hour long assesment for the below job at SHL
# Job D...
#   [38/65] Find me 1 hour long assesment for the below job at SHL
# Job D...
#   [39/65] Find me 1 hour long assesment for the below job at SHL
# Job D...
#   [40/65] ICICI Bank Assistant Admin, Experience required 0-2 years, t...
#   [41/65] ICICI Bank Assistant Admin, Experience required 0-2 years, t...
#   [42/65] ICICI Bank Assistant Admin, Experience required 0-2 years, t...
#   [43/65] ICICI Bank Assistant Admin, Experience required 0-2 years, t...
#   [44/65] ICICI Bank Assistant Admin, Experience required 0-2 years, t...
#   [45/65] ICICI Bank Assistant Admin, Experience required 0-2 years, t...
#   [46/65] We're looking for a Marketing Manager who can drive Recro’s ...
#   [47/65] We're looking for a Marketing Manager who can drive Recro’s ...
#   [48/65] We're looking for a Marketing Manager who can drive Recro’s ...
#   [49/65] We're looking for a Marketing Manager who can drive Recro’s ...
#   [50/65] We're looking for a Marketing Manager who can drive Recro’s ...
#   [51/65] Based on the JD below recommend me assessment for the Consul...
#   [52/65] Based on the JD below recommend me assessment for the Consul...
#   [53/65] Based on the JD below recommend me assessment for the Consul...
#   [54/65] Based on the JD below recommend me assessment for the Consul...
#   [55/65] Based on the JD below recommend me assessment for the Consul...
#   [56/65] I want to hire a Senior Data Analyst with 5 years of experie...
#   [57/65] I want to hire a Senior Data Analyst with 5 years of experie...
#   [58/65] I want to hire a Senior Data Analyst with 5 years of experie...
#   [59/65] I want to hire a Senior Data Analyst with 5 years of experie...
#   [60/65] I want to hire a Senior Data Analyst with 5 years of experie...
#   [61/65] I want to hire a Senior Data Analyst with 5 years of experie...
#   [62/65] I want to hire a Senior Data Analyst with 5 years of experie...
#   [63/65] I want to hire a Senior Data Analyst with 5 years of experie...
#   [64/65] I want to hire a Senior Data Analyst with 5 years of experie...
#   [65/65] I want to hire a Senior Data Analyst with 5 years of experie...
#
# ✓ Saved predictions to: predictions.csv
#   Total rows: 650
#   Format: query, assessment_url

# %% [markdown]
# After implementing hybrid search(Semantic + BM25)

# %% [markdown]
# (venv) C:\Users\hbish\Desktop\Shl Recommendation System>python src/evaluation/metrics.py
# Loading recommender system...
# Metadata columns: ['name', 'url', 'description', 'product_type', 'duration', 'remote_support', 'adaptive_support', 'test_type']
# Building BM25 index...
# ✓ BM25 Ready
# ⚠ Warning: GOOGLE_API_KEY not set. LLM features disabled.
# ✓ Loaded 377 assessments
#
# ======================================================================
# EVALUATING ON TRAIN SET
# ======================================================================
#
# Generating predictions for 10 queries...
#   [1/10] Based on the JD below recommend me assessment for the Consul...
#   [2/10] Content Writer required, expert in English and SEO....
#   [3/10] Find me 1 hour long assesment for the below job at SHL
# Job D...
#   [4/10] I am hiring for Java developers who can also collaborate eff...
#   [5/10] I am looking for a COO for my company in China and I want to...
#   [6/10] I want to hire a Senior Data Analyst with 5 years of experie...
#   [7/10] I want to hire new graduates for a sales role in my company,...
#   [8/10] ICICI Bank Assistant Admin, Experience required 0-2 years, t...
#   [9/10] KEY RESPONSIBITILES:
#
# Manage the sound-scape of the station ...
#   [10/10] We're looking for a Marketing Manager who can drive Recro’s ...
#
# ======================================================================
# EVALUATION RESULTS
# ======================================================================
# Mean Recall@5: 0.1689
# Mean Recall@10: 0.2289
#
# ======================================================================
# PER-QUERY ANALYSIS
# ======================================================================
#
# Best performing queries:
#   Recall@10: 0.6000 - Content Writer required, expert in English and SEO....
#   Recall@10: 0.6000 - I am hiring for Java developers who can also collaborate eff...
#   Recall@10: 0.5000 - I want to hire a Senior Data Analyst with 5 years of experie...
#
# Worst performing queries:
#   Recall@10: 0.0000 - Based on the JD below recommend me assessment for the Consul...
#   Recall@10: 0.0000 - ICICI Bank Assistant Admin, Experience required 0-2 years, t...
#   Recall@10: 0.0000 - We're looking for a Marketing Manager who can drive Recro’s ...
#
# ======================================================================
# GENERATING TEST PREDICTIONS
# ======================================================================
#
# Generating predictions for 65 test queries...
#   [1/65] I am hiring for Java developers who can also collaborate eff...
#   [2/65] I am hiring for Java developers who can also collaborate eff...
#   [3/65] I am hiring for Java developers who can also collaborate eff...
#   [4/65] I am hiring for Java developers who can also collaborate eff...
#   [5/65] I am hiring for Java developers who can also collaborate eff...
#   [6/65] I want to hire new graduates for a sales role in my company,...
#   [7/65] I want to hire new graduates for a sales role in my company,...
#   [8/65] I want to hire new graduates for a sales role in my company,...
#   [9/65] I want to hire new graduates for a sales role in my company,...
#   [10/65] I want to hire new graduates for a sales role in my company,...
#   [11/65] I want to hire new graduates for a sales role in my company,...
#   [12/65] I want to hire new graduates for a sales role in my company,...
#   [13/65] I want to hire new graduates for a sales role in my company,...
#   [14/65] I want to hire new graduates for a sales role in my company,...
#   [15/65] I am looking for a COO for my company in China and I want to...
#   [16/65] I am looking for a COO for my company in China and I want to...
#   [17/65] I am looking for a COO for my company in China and I want to...
#   [18/65] I am looking for a COO for my company in China and I want to...
#   [19/65] I am looking for a COO for my company in China and I want to...
#   [20/65] I am looking for a COO for my company in China and I want to...
#   [21/65] KEY RESPONSIBITILES:
#
# Manage the sound-scape of the station ...
#   [22/65] KEY RESPONSIBITILES:
#
# Manage the sound-scape of the station ...
#   [23/65] KEY RESPONSIBITILES:
#
# Manage the sound-scape of the station ...
#   [24/65] KEY RESPONSIBITILES:
#
# Manage the sound-scape of the station ...
#   [25/65] KEY RESPONSIBITILES:
#
# Manage the sound-scape of the station ...
#   [26/65] Content Writer required, expert in English and SEO....
#   [27/65] Content Writer required, expert in English and SEO....
#   [28/65] Content Writer required, expert in English and SEO....
#   [29/65] Content Writer required, expert in English and SEO....
#   [30/65] Content Writer required, expert in English and SEO....
#   [31/65] Find me 1 hour long assesment for the below job at SHL
# Job D...
#   [32/65] Find me 1 hour long assesment for the below job at SHL
# Job D...
#   [33/65] Find me 1 hour long assesment for the below job at SHL
# Job D...
#   [34/65] Find me 1 hour long assesment for the below job at SHL
# Job D...
#   [35/65] Find me 1 hour long assesment for the below job at SHL
# Job D...
#   [36/65] Find me 1 hour long assesment for the below job at SHL
# Job D...
#   [37/65] Find me 1 hour long assesment for the below job at SHL
# Job D...
#   [38/65] Find me 1 hour long assesment for the below job at SHL
# Job D...
#   [39/65] Find me 1 hour long assesment for the below job at SHL
# Job D...
#   [40/65] ICICI Bank Assistant Admin, Experience required 0-2 years, t...
#   [41/65] ICICI Bank Assistant Admin, Experience required 0-2 years, t...
#   [42/65] ICICI Bank Assistant Admin, Experience required 0-2 years, t...
#   [43/65] ICICI Bank Assistant Admin, Experience required 0-2 years, t...
#   [44/65] ICICI Bank Assistant Admin, Experience required 0-2 years, t...
#   [45/65] ICICI Bank Assistant Admin, Experience required 0-2 years, t...
#   [46/65] We're looking for a Marketing Manager who can drive Recro’s ...
#   [47/65] We're looking for a Marketing Manager who can drive Recro’s ...
#   [48/65] We're looking for a Marketing Manager who can drive Recro’s ...
#   [49/65] We're looking for a Marketing Manager who can drive Recro’s ...
#   [50/65] We're looking for a Marketing Manager who can drive Recro’s ...
#   [51/65] Based on the JD below recommend me assessment for the Consul...
#   [52/65] Based on the JD below recommend me assessment for the Consul...
#   [53/65] Based on the JD below recommend me assessment for the Consul...
#   [54/65] Based on the JD below recommend me assessment for the Consul...
#   [55/65] Based on the JD below recommend me assessment for the Consul...
#   [56/65] I want to hire a Senior Data Analyst with 5 years of experie...
#   [57/65] I want to hire a Senior Data Analyst with 5 years of experie...
#   [58/65] I want to hire a Senior Data Analyst with 5 years of experie...
#   [59/65] I want to hire a Senior Data Analyst with 5 years of experie...
#   [60/65] I want to hire a Senior Data Analyst with 5 years of experie...
#   [61/65] I want to hire a Senior Data Analyst with 5 years of experie...
#   [62/65] I want to hire a Senior Data Analyst with 5 years of experie...
#   [63/65] I want to hire a Senior Data Analyst with 5 years of experie...
#   [64/65] I want to hire a Senior Data Analyst with 5 years of experie...
#   [65/65] I want to hire a Senior Data Analyst with 5 years of experie...
#
# ✓ Saved predictions to: predictions.csv
#   Total rows: 620
#   Format: query, assessment_url
