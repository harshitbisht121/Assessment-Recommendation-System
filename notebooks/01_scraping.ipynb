# %% [markdown]
# (venv) C:\Users\hbish\Desktop\Shl Recommendation System>python src/scraper/shl_scraper.py
#
# ============================================================
# SCRAPING: Individual Test Solutions (Pages 1-32)
# ============================================================
#
# [STEP 1] Collecting product URLs from Individual Test Solutions pages...
#
# Scanning catalog page 1/32: https://www.shl.com/products/product-catalog/?start=0&type=1
# ✓ Found 12 new Individual Test Solutions
#   Total collected: 12
#
# Scanning catalog page 2/32: https://www.shl.com/products/product-catalog/?start=12&type=1
# ✓ Found 12 new Individual Test Solutions
#   Total collected: 24
#
# Scanning catalog page 3/32: https://www.shl.com/products/product-catalog/?start=24&type=1
# ✓ Found 12 new Individual Test Solutions
#   Total collected: 36
#
# Scanning catalog page 4/32: https://www.shl.com/products/product-catalog/?start=36&type=1
# ✓ Found 12 new Individual Test Solutions
#   Total collected: 48
#
# Scanning catalog page 5/32: https://www.shl.com/products/product-catalog/?start=48&type=1
# ✓ Found 12 new Individual Test Solutions
#   Total collected: 60
#
# Scanning catalog page 6/32: https://www.shl.com/products/product-catalog/?start=60&type=1
# ✓ Found 12 new Individual Test Solutions
#   Total collected: 72
#
# Scanning catalog page 7/32: https://www.shl.com/products/product-catalog/?start=72&type=1
# ✓ Found 12 new Individual Test Solutions
#   Total collected: 84
#
# Scanning catalog page 8/32: https://www.shl.com/products/product-catalog/?start=84&type=1
# ✓ Found 12 new Individual Test Solutions
#   Total collected: 96
#
# Scanning catalog page 9/32: https://www.shl.com/products/product-catalog/?start=96&type=1
# ✓ Found 12 new Individual Test Solutions
#   Total collected: 108
#
# Scanning catalog page 10/32: https://www.shl.com/products/product-catalog/?start=108&type=1
# ✓ Found 12 new Individual Test Solutions
#   Total collected: 120
#
# Scanning catalog page 11/32: https://www.shl.com/products/product-catalog/?start=120&type=1
# ✓ Found 12 new Individual Test Solutions
#   Total collected: 132
#
# Scanning catalog page 12/32: https://www.shl.com/products/product-catalog/?start=132&type=1
# ✓ Found 12 new Individual Test Solutions
#   Total collected: 144
#
# Scanning catalog page 13/32: https://www.shl.com/products/product-catalog/?start=144&type=1
# ✓ Found 12 new Individual Test Solutions
#   Total collected: 156
#
# Scanning catalog page 14/32: https://www.shl.com/products/product-catalog/?start=156&type=1
# ✓ Found 12 new Individual Test Solutions
#   Total collected: 168
#
# Scanning catalog page 15/32: https://www.shl.com/products/product-catalog/?start=168&type=1
# ✓ Found 12 new Individual Test Solutions
#   Total collected: 180
#
# Scanning catalog page 16/32: https://www.shl.com/products/product-catalog/?start=180&type=1
# ✓ Found 12 new Individual Test Solutions
#   Total collected: 192
#
# Scanning catalog page 17/32: https://www.shl.com/products/product-catalog/?start=192&type=1
# ✓ Found 12 new Individual Test Solutions
#   Total collected: 204
#
# Scanning catalog page 18/32: https://www.shl.com/products/product-catalog/?start=204&type=1
# ✓ Found 12 new Individual Test Solutions
#   Total collected: 216
#
# Scanning catalog page 19/32: https://www.shl.com/products/product-catalog/?start=216&type=1
# ✓ Found 12 new Individual Test Solutions
#   Total collected: 228
#
# Scanning catalog page 20/32: https://www.shl.com/products/product-catalog/?start=228&type=1
# ✓ Found 12 new Individual Test Solutions
#   Total collected: 240
#
# Scanning catalog page 21/32: https://www.shl.com/products/product-catalog/?start=240&type=1
# ✓ Found 12 new Individual Test Solutions
#   Total collected: 252
#
# Scanning catalog page 22/32: https://www.shl.com/products/product-catalog/?start=252&type=1
# ✓ Found 12 new Individual Test Solutions
#   Total collected: 264
#
# Scanning catalog page 23/32: https://www.shl.com/products/product-catalog/?start=264&type=1
# ✓ Found 12 new Individual Test Solutions
#   Total collected: 276
#
# Scanning catalog page 24/32: https://www.shl.com/products/product-catalog/?start=276&type=1
# Scanning catalog page 25/32: https://www.shl.com/products/product-catalog/?start=288&type=1
# ✓ Found 12 new Individual Test Solutions
#   Total collected: 300
#
# Scanning catalog page 26/32: https://www.shl.com/products/product-catalog/?start=300&type=1
# ✓ Found 12 new Individual Test Solutions
#   Total collected: 312
#
# Scanning catalog page 27/32: https://www.shl.com/products/product-catalog/?start=312&type=1
# ✓ Found 12 new Individual Test Solutions
#   Total collected: 324
#
# Scanning catalog page 28/32: https://www.shl.com/products/product-catalog/?start=324&type=1
# ✓ Found 12 new Individual Test Solutions
#   Total collected: 336
#
# Scanning catalog page 29/32: https://www.shl.com/products/product-catalog/?start=336&type=1
# ✓ Found 12 new Individual Test Solutions
#   Total collected: 348
#
# Scanning catalog page 30/32: https://www.shl.com/products/product-catalog/?start=348&type=1
# ✓ Found 12 new Individual Test Solutions
#   Total collected: 360
#
# Scanning catalog page 31/32: https://www.shl.com/products/product-catalog/?start=360&type=1
# ✓ Found 12 new Individual Test Solutions
#   Total collected: 372
#
# Scanning catalog page 32/32: https://www.shl.com/products/product-catalog/?start=372&type=1
# ✓ Found 5 new Individual Test Solutions
#   Total collected: 377

# %% [markdown]
# ============================================================
# [STEP 2] Scraping 377 Individual Test Solutions...
# ============================================================
#
# [1/377] Visiting: https://www.shl.com/products/product-catalog/view/360-digital-report/
#   ✔ 360 Digital Report - Types: P, A, K, S, B
#
# [2/377] Visiting: https://www.shl.com/products/product-catalog/view/360-multi-rater-feedback-system-mfs/
#   ✔ 360° Multi-Rater Feedback System (MFS) - Types: P, A, K, S, B
#
# [3/377] Visiting: https://www.shl.com/products/product-catalog/view/accounts-payable-new/
#   ✔ Accounts Payable (New) - Types: P, A, K, S, B
#
# [4/377] Visiting: https://www.shl.com/products/product-catalog/view/accounts-payable-simulation-new/
#   ✔ Accounts Payable Simulation (New) - Types: P, A, K, S, B
#
# [5/377] Visiting: https://www.shl.com/products/product-catalog/view/accounts-receivable-new/
#   ✔ Accounts Receivable (New) - Types: P, A, K, S, B
#
# [6/377] Visiting: https://www.shl.com/products/product-catalog/view/accounts-receivable-simulation-new/
#   ✔ Accounts Receivable Simulation (New) - Types: P, A, K, S, B
#
# [7/377] Visiting: https://www.shl.com/products/product-catalog/view/ado-net-new/
#   ✔ ADO.NET (New) - Types: P, A, K, S, B
#
# [8/377] Visiting: https://www.shl.com/products/product-catalog/view/adobe-experience-manager-new/
#   ✔ Adobe Experience Manager (New) - Types: P, A, K, S, B
#
# [9/377] Visiting: https://www.shl.com/products/product-catalog/view/adobe-photoshop-cc/
#   ✔ Adobe Photoshop CC - Types: P, A, K, S, B
#
# [10/377] Visiting: https://www.shl.com/products/product-catalog/view/aeronautical-engineering-new/
#   ✔ Aeronautical Engineering (New) - Types: P, A, K, S, B
#
# [11/377] Visiting: https://www.shl.com/products/product-catalog/view/aerospace-engineering-new/
#   ✔ Aerospace Engineering (New) - Types: P, A, K, S, B
#
# [12/377] Visiting: https://www.shl.com/products/product-catalog/view/agile-software-development/
#   ✔ Agile Software Development - Types: P, A, K, S, B
#
# [13/377] Visiting: https://www.shl.com/products/product-catalog/view/agile-testing-new/
#   ✔ Agile Testing (New) - Types: P, A, K, S, B
#
# [14/377] Visiting: https://www.shl.com/products/product-catalog/view/ai-skills/
#   ✔ AI Skills - Types: P, A, K, S, B
#
# [15/377] Visiting: https://www.shl.com/products/product-catalog/view/amazon-web-services-aws-development-new/
#   ✔ Amazon Web Services (AWS) Development (New) - Types: P, A, K, S, B
#
# [16/377] Visiting: https://www.shl.com/products/product-catalog/view/android-development-new/
#   ✔ Android Development (New) - Types: P, A, K, S, B
#
# [17/377] Visiting: https://www.shl.com/products/product-catalog/view/angular-6-new/
#   ✔ Angular 6 (New) - Types: P, A, K, S, B
#
# [18/377] Visiting: https://www.shl.com/products/product-catalog/view/angularjs-new/
#   ✔ AngularJS (New) - Types: P, A, K, S, B
#
# [19/377] Visiting: https://www.shl.com/products/product-catalog/view/apache-hadoop-extensions-new/
#   ✔ Apache Hadoop Extensions (New) - Types: P, A, K, S, B
#
# [20/377] Visiting: https://www.shl.com/products/product-catalog/view/apache-hadoop-new/
#   ✔ Apache Hadoop (New) - Types: P, A, K, S, B
#
# [21/377] Visiting: https://www.shl.com/products/product-catalog/view/apache-hbase-new/
#   ✔ Apache HBase (New) - Types: P, A, K, S, B
#
# [22/377] Visiting: https://www.shl.com/products/product-catalog/view/apache-hive-new/
#   ✔ Apache Hive (New) - Types: P, A, K, S, B
#
# [23/377] Visiting: https://www.shl.com/products/product-catalog/view/apache-kafka-new/
#   ✔ Apache Kafka (New) - Types: P, A, K, S, B
#
# [24/377] Visiting: https://www.shl.com/products/product-catalog/view/apache-pig-new/
#   ✔ Apache Pig (New) - Types: P, A, K, S, B
#
# [25/377] Visiting: https://www.shl.com/products/product-catalog/view/apache-spark-new/
#   ✔ Apache Spark (New) - Types: P, A, K, S, B
#
# [26/377] Visiting: https://www.shl.com/products/product-catalog/view/asp-net-4-5/
#   ✔ ASP.NET 4.5 - Types: P, A, K, S, B
#
# [27/377] Visiting: https://www.shl.com/products/product-catalog/view/asp-net-with-c-new/
#   ✔ ASP .NET with C# (New) - Types: P, A, K, S, B
#
# [28/377] Visiting: https://www.shl.com/products/product-catalog/view/assessment-and-development-center-exercises/
#   ✔ Assessment and Development Center Exercises - Types: P, A, K, S, B
#
# [29/377] Visiting: https://www.shl.com/products/product-catalog/view/automata-data-science-new/
#   ✔ Automata Data Science (New) - Types: P, A, K, S, B
#
# [30/377] Visiting: https://www.shl.com/products/product-catalog/view/automata-data-science-pro-new/
#   ✔ Automata Data Science Pro (New) - Types: P, A, K, S, B
#
# [31/377] Visiting: https://www.shl.com/products/product-catalog/view/automata-fix-new/
#   ✔ Automata - Fix (New) - Types: P, A, K, S, B
#
# [32/377] Visiting: https://www.shl.com/products/product-catalog/view/automata-front-end/
#   ✔ Automata Front End - Types: P, A, K, S, B
#
# [33/377] Visiting: https://www.shl.com/products/product-catalog/view/automata-new/
#   ✔ Automata (New) - Types: P, A, K, S, B
#
# [34/377] Visiting: https://www.shl.com/products/product-catalog/view/automata-pro-new/
#   ✔ Automata Pro (New) - Types: P, A, K, S, B
#
# [35/377] Visiting: https://www.shl.com/products/product-catalog/view/automata-selenium/
#   ✔ Automata Selenium - Types: P, A, K, S, B
#
# [36/377] Visiting: https://www.shl.com/products/product-catalog/view/automata-sql-new/
#   ✔ Automata - SQL (New) - Types: P, A, K, S, B
#
# [37/377] Visiting: https://www.shl.com/products/product-catalog/view/automation-anywhere-rpa-development-new/
#   ✔ Automation Anywhere RPA Development (New) - Types: P, A, K, S, B
#
# [38/377] Visiting: https://www.shl.com/products/product-catalog/view/automotive-engineering-new/
#   ✔ Automotive Engineering (New) - Types: P, A, K, S, B
#
# [39/377] Visiting: https://www.shl.com/products/product-catalog/view/basic-biology-new/
#   ✔ Basic Biology (New) - Types: P, A, K, S, B
#
# [40/377] Visiting: https://www.shl.com/products/product-catalog/view/basic-computer-literacy-windows-10-new/
#   ✔ Basic Computer Literacy (Windows 10) (New) - Types: P, A, K, S, B
#
# [41/377] Visiting: https://www.shl.com/products/product-catalog/view/basic-statistics-new/
#   ✔ Basic Statistics (New) - Types: P, A, K, S, B
#
# [42/377] Visiting: https://www.shl.com/products/product-catalog/view/biochemistry-new/
#   ✔ Biochemistry (New) - Types: P, A, K, S, B
#
# [43/377] Visiting: https://www.shl.com/products/product-catalog/view/biotech-lab-techniques-new/
#   ✔ Biotech Lab Techniques (New) - Types: P, A, K, S, B
#
# [44/377] Visiting: https://www.shl.com/products/product-catalog/view/biztalk-new/
#   ✔ BizTalk (New) - Types: P, A, K, S, B
#
# [45/377] Visiting: https://www.shl.com/products/product-catalog/view/business-communication-adaptive/
#   ✔ Business Communication (adaptive) - Types: P, A, K, S, B
#
# [46/377] Visiting: https://www.shl.com/products/product-catalog/view/business-communications/
#   ✔ Business Communications - Types: P, A, K, S, B
#
# [47/377] Visiting: https://www.shl.com/products/product-catalog/view/c-programming-new-4039/
#   ✔ C# Programming (New) - Types: P, A, K, S, B
#
# [48/377] Visiting: https://www.shl.com/products/product-catalog/view/c-programming-new-4122/
#   ✔ C++ Programming (New) - Types: P, A, K, S, B
#
# [49/377] Visiting: https://www.shl.com/products/product-catalog/view/c-programming-new/
#   ✔ C Programming (New) - Types: P, A, K, S, B
#
# [50/377] Visiting: https://www.shl.com/products/product-catalog/view/cardiology-and-diabetes-management-new/
#   ✔ Cardiology and Diabetes Management (New) - Types: P, A, K, S, B
#
# [51/377] Visiting: https://www.shl.com/products/product-catalog/view/ceramic-engineering-new/
#   ✔ Ceramic Engineering (New) - Types: P, A, K, S, B
#
# [52/377] Visiting: https://www.shl.com/products/product-catalog/view/chemical-engineering-new/
#   ✔ Chemical Engineering (New) - Types: P, A, K, S, B
#
# [53/377] Visiting: https://www.shl.com/products/product-catalog/view/cisco-appdynamics-new/
#   ✔ Cisco AppDynamics (New) - Types: P, A, K, S, B
#
# [54/377] Visiting: https://www.shl.com/products/product-catalog/view/civil-engineering-new/
#   ✔ Civil Engineering (New) - Types: P, A, K, S, B
#
# [55/377] Visiting: https://www.shl.com/products/product-catalog/view/cloud-computing-new/
#   ✔ Cloud Computing (New) - Types: P, A, K, S, B
#
# [56/377] Visiting: https://www.shl.com/products/product-catalog/view/cobol-programming-new/
#   ✔ COBOL Programming (New) - Types: P, A, K, S, B
#
# [57/377] Visiting: https://www.shl.com/products/product-catalog/view/computer-science-new/
#   ✔ Computer Science (New) - Types: P, A, K, S, B
#
# [58/377] Visiting: https://www.shl.com/products/product-catalog/view/contact-center-call-simulation-new/
#   ✔ Contact Center Call Simulation (New) - Types: P, A, K, S, B
#
# [59/377] Visiting: https://www.shl.com/products/product-catalog/view/conversational-multichat-simulation/
#   ✔ Conversational Multichat Simulation - Types: P, A, K, S, B
#
# [60/377] Visiting: https://www.shl.com/products/product-catalog/view/core-java-advanced-level-new/
#   ✔ Core Java (Advanced Level) (New) - Types: P, A, K, S, B
#
# [61/377] Visiting: https://www.shl.com/products/product-catalog/view/core-java-entry-level-new/
#   ✔ Core Java (Entry Level) (New) - Types: P, A, K, S, B
#
# [62/377] Visiting: https://www.shl.com/products/product-catalog/view/count-out-the-money/
#   ✔ Count Out The Money - Types: P, A, K, S, B
#
# [63/377] Visiting: https://www.shl.com/products/product-catalog/view/css3-new/
#   ✔ CSS3 (New) - Types: P, A, K, S, B
#
# [64/377] Visiting: https://www.shl.com/products/product-catalog/view/culinary-skills-new/
#   ✔ Culinary Skills (New) - Types: P, A, K, S, B
#
# [65/377] Visiting: https://www.shl.com/products/product-catalog/view/customer-service-phone-simulation/
#   ✔ Customer Service Phone Simulation - Types: P, A, K, S, B
#
# [66/377] Visiting: https://www.shl.com/products/product-catalog/view/customer-service-phone-solution/
#   ✔ Customer Service Phone Solution - Types: P, A, K, S, B
#
# [67/377] Visiting: https://www.shl.com/products/product-catalog/view/cyber-risk-new/
#   ✔ Cyber Risk (New) - Types: P, A, K, S, B
#
# [68/377] Visiting: https://www.shl.com/products/product-catalog/view/data-entry-alphanumeric-split-screen-us/
#   ✔ Data Entry Alphanumeric Split Screen - US - Types: P, A, K, S, B
#
# [69/377] Visiting: https://www.shl.com/products/product-catalog/view/data-entry-new/
#   ✔ Data Entry (New) - Types: P, A, K, S, B
#
# [70/377] Visiting: https://www.shl.com/products/product-catalog/view/data-entry-numeric-split-screen-us/
#   ✔ Data Entry Numeric Split Screen - US - Types: P, A, K, S, B
#
# [71/377] Visiting: https://www.shl.com/products/product-catalog/view/data-entry-ten-key-split-screen/
#   ✔ Data Entry Ten Key Split Screen - Types: P, A, K, S, B
#
# [72/377] Visiting: https://www.shl.com/products/product-catalog/view/data-science-new/
#   ✔ Data Science (New) - Types: P, A, K, S, B
#
# [73/377] Visiting: https://www.shl.com/products/product-catalog/view/data-warehousing-concepts/
#   ✔ Data Warehousing Concepts - Types: P, A, K, S, B
#
# [74/377] Visiting: https://www.shl.com/products/product-catalog/view/dependability-and-safety-instrument-dsi/
#   ✔ Dependability and Safety Instrument (DSI) - Types: P, A, K, S, B
#
# [75/377] Visiting: https://www.shl.com/products/product-catalog/view/dermatology-new/
#   ✔ Dermatology (New) - Types: P, A, K, S, B
#
# [76/377] Visiting: https://www.shl.com/products/product-catalog/view/desktop-support-new/
#   ✔ Desktop Support (New) - Types: P, A, K, S, B
#
# [77/377] Visiting: https://www.shl.com/products/product-catalog/view/digital-advertising-new/
#   ✔ Digital Advertising (New) - Types: P, A, K, S, B
#
# [78/377] Visiting: https://www.shl.com/products/product-catalog/view/digital-readiness-development-report-manager/
#   ✔ Digital Readiness Development Report - Manager - Types: P, A, K, S, B
#
# [79/377] Visiting: https://www.shl.com/products/product-catalog/view/digital-readiness-development-report/
#   ✔ Digital Readiness Development Report - IC - Types: P, A, K, S, B
#
# [80/377] Visiting: https://www.shl.com/products/product-catalog/view/docker-new/
#   ✔ Docker (New) - Types: P, A, K, S, B
#
# [81/377] Visiting: https://www.shl.com/products/product-catalog/view/dojo-new/
#   ✔ Dojo (New) - Types: P, A, K, S, B
#
# [82/377] Visiting: https://www.shl.com/products/product-catalog/view/drupal-new/
#   ✔ Drupal (New) - Types: P, A, K, S, B
#
# [83/377] Visiting: https://www.shl.com/products/product-catalog/view/dsi-v1-1-interpretation-report/
#   ✔ DSI v1.1 Interpretation Report - Types: P, A, K, S, B
#
# [84/377] Visiting: https://www.shl.com/products/product-catalog/view/econometrics-new/
#   ✔ Econometrics (New) - Types: P, A, K, S, B
#
# [85/377] Visiting: https://www.shl.com/products/product-catalog/view/economics-new/
#   ✔ Economics (New) - Types: P, A, K, S, B
#
# [86/377] Visiting: https://www.shl.com/products/product-catalog/view/electrical-and-electronics-engineering-new/
#   ✔ Electrical and Electronics Engineering (New) - Types: P, A, K, S, B
#
# [87/377] Visiting: https://www.shl.com/products/product-catalog/view/electrical-engineering-new/
#   ✔ Electrical Engineering (New) - Types: P, A, K, S, B
#
# [88/377] Visiting: https://www.shl.com/products/product-catalog/view/electronics-and-embedded-systems-engineering-new/
#   ✔ Electronics and Embedded Systems Engineering (New) - Types: P, A, K, S, B
#
# [89/377] Visiting: https://www.shl.com/products/product-catalog/view/electronics-and-semiconductor-engineering-new/
#   ✔ Electronics and Semiconductor Engineering (New) - Types: P, A, K, S, B
#
# [90/377] Visiting: https://www.shl.com/products/product-catalog/view/electronics-and-telecommunications-engineering-new/
#   ✔ Electronics & Telecommunications Engineering (New) - Types: P, A, K, S, B
#
# [91/377] Visiting: https://www.shl.com/products/product-catalog/view/english-comprehension-new/
#   ✔ English Comprehension (New) - Types: P, A, K, S, B
#
# [92/377] Visiting: https://www.shl.com/products/product-catalog/view/enterprise-java-beans-new/
#   ✔ Enterprise Java Beans (New) - Types: P, A, K, S, B
#
# [93/377] Visiting: https://www.shl.com/products/product-catalog/view/enterprise-leadership-report-2-0/
#   ✔ Enterprise Leadership Report 2.0 - Types: P, A, K, S, B
#
# [94/377] Visiting: https://www.shl.com/products/product-catalog/view/enterprise-leadership-report/
#   ✔ Enterprise Leadership Report 1.0 - Types: P, A, K, S, B
#
# [95/377] Visiting: https://www.shl.com/products/product-catalog/view/entry-level-cashier-solution/
#   ✔ Entry Level Cashier Solution - Types: P, A, K, S, B
#
# [96/377] Visiting: https://www.shl.com/products/product-catalog/view/entry-level-customer-serv-retail-and-contact-center/
#   ✔ Entry Level Customer Serv-Retail & Contact Center - Types: P, A, K, S, B
#
# [97/377] Visiting: https://www.shl.com/products/product-catalog/view/entry-level-customer-service-general-solution/
#   ✔ Entry Level Customer Service (General) Solution - Types: P, A, K, S, B
#
# [98/377] Visiting: https://www.shl.com/products/product-catalog/view/entry-level-hotel-front-desk-solution/
#   ✔ Entry Level Hotel Front Desk Solution - Types: P, A, K, S, B
#
# [99/377] Visiting: https://www.shl.com/products/product-catalog/view/entry-level-sales-solution/
#   ✔ Entry Level Sales Solution - Types: P, A, K, S, B
#
# [100/377] Visiting: https://www.shl.com/products/product-catalog/view/entry-level-technical-support-solution/
#   ✔ Entry Level Technical Support Solution - Types: P, A, K, S, B
#
# [101/377] Visiting: https://www.shl.com/products/product-catalog/view/essential-focus-8-0/
#   ✔ Manufacturing & Industrial - Essential Focus 8.0 - Types: P, A, K, S, B
#
# [102/377] Visiting: https://www.shl.com/products/product-catalog/view/etl-testing-new/
#   ✔ ETL Testing (New) - Types: P, A, K, S, B
#
# [103/377] Visiting: https://www.shl.com/products/product-catalog/view/executive-scenarios-narrative-report/
#   ✔ Executive Scenarios Narrative Report - Types: P, A, K, S, B
#
# [104/377] Visiting: https://www.shl.com/products/product-catalog/view/executive-scenarios-profile-report/
#   ✔ Executive Scenarios Profile Report - Types: P, A, K, S, B
#
# [105/377] Visiting: https://www.shl.com/products/product-catalog/view/executive-scenarios/
#   ✔ Executive Scenarios - Types: P, A, K, S, B
#
# [106/377] Visiting: https://www.shl.com/products/product-catalog/view/expressjs-new/
#   ✔ ExpressJS (New) - Types: P, A, K, S, B
#
# [107/377] Visiting: https://www.shl.com/products/product-catalog/view/filing-names-r1/
#   ✔ Filing - Names (R1) - Types: P, A, K, S, B
#
# [108/377] Visiting: https://www.shl.com/products/product-catalog/view/filing-numbers/
#   ✔ Filing - Numbers - Types: P, A, K, S, B
#
# [109/377] Visiting: https://www.shl.com/products/product-catalog/view/financial-accounting-new/
#   ✔ Financial Accounting (New) - Types: P, A, K, S, B
#
# [110/377] Visiting: https://www.shl.com/products/product-catalog/view/financial-and-banking-services-new/
#   ✔ Financial and Banking Services (New) - Types: P, A, K, S, B
#
# [111/377] Visiting: https://www.shl.com/products/product-catalog/view/fire-engineering-new/
#   ✔ Fire Engineering (New) - Types: P, A, K, S, B
#
# [112/377] Visiting: https://www.shl.com/products/product-catalog/view/following-instructions-v1-uk-r1/
#   ✔ Following Instructions v1 - UK (R1) - Types: P, A, K, S, B
#
# [113/377] Visiting: https://www.shl.com/products/product-catalog/view/following-instructions-v1-us-r2/
#   ✔ Following Instructions v1 - US (R2) - Types: P, A, K, S, B
#
# [114/377] Visiting: https://www.shl.com/products/product-catalog/view/food-and-beverage-services-new/
#   ✔ Food and Beverage Services (New) - Types: P, A, K, S, B
#
# [115/377] Visiting: https://www.shl.com/products/product-catalog/view/food-science-new/
#   ✔ Food Science (New) - Types: P, A, K, S, B
#
# [116/377] Visiting: https://www.shl.com/products/product-catalog/view/front-office-management-new/
#   ✔ Front Office Management (New) - Types: P, A, K, S, B
#
# [117/377] Visiting: https://www.shl.com/products/product-catalog/view/fundamentals-of-chemistry-new/
#   ✔ Fundamentals of Chemistry (New) - Types: P, A, K, S, B
#
# [118/377] Visiting: https://www.shl.com/products/product-catalog/view/fundamentals-of-physics-new/
#   ✔ Fundamentals of Physics (New) - Types: P, A, K, S, B
#
# [119/377] Visiting: https://www.shl.com/products/product-catalog/view/general-diseases-new/
#   ✔ General Diseases (New) - Types: P, A, K, S, B
#
# [120/377] Visiting: https://www.shl.com/products/product-catalog/view/geoinformatics-engineering-new/
#   ✔ Geoinformatics Engineering (New) - Types: P, A, K, S, B
#
# [121/377] Visiting: https://www.shl.com/products/product-catalog/view/geoscience-engineering-new/
#   ✔ Geoscience Engineering (New) - Types: P, A, K, S, B
#
# [122/377] Visiting: https://www.shl.com/products/product-catalog/view/git-new/
#   ✔ GIT (New) - Types: P, A, K, S, B
#
# [123/377] Visiting: https://www.shl.com/products/product-catalog/view/global-skills-assessment/
#   ✔ Global Skills Assessment - Types: P, A, K, S, B
#
# [124/377] Visiting: https://www.shl.com/products/product-catalog/view/global-skills-development-report/
#   ✔ Global Skills Development Report - Types: P, A, K, S, B
#
# [125/377] Visiting: https://www.shl.com/products/product-catalog/view/graduate-scenarios-narrative-report/
#   ✔ Graduate Scenarios Narrative Report - Types: P, A, K, S, B
#
# [126/377] Visiting: https://www.shl.com/products/product-catalog/view/graduate-scenarios-profile-report/
#   ✔ Graduate Scenarios Profile Report - Types: P, A, K, S, B
#
# [127/377] Visiting: https://www.shl.com/products/product-catalog/view/graduate-scenarios/
#   ✔ Graduate Scenarios - Types: P, A, K, S, B
#
# [128/377] Visiting: https://www.shl.com/products/product-catalog/view/hibernate-new/
#   ✔ Hibernate (New) - Types: P, A, K, S, B
#
# [129/377] Visiting: https://www.shl.com/products/product-catalog/view/hipaa-security/
#   ✔ HIPAA (Security) - Types: P, A, K, S, B
#
# [130/377] Visiting: https://www.shl.com/products/product-catalog/view/hipo-assessment-report-1-0/
#   ✔ HiPo Assessment Report 1.0 - Types: P, A, K, S, B
#
# [131/377] Visiting: https://www.shl.com/products/product-catalog/view/hipo-assessment-report-2-0/
#   ✔ HiPo Assessment Report 2.0 - Types: P, A, K, S, B
#
# [132/377] Visiting: https://www.shl.com/products/product-catalog/view/hipo-unlocking-potential-report-2-0/
#   ✔ HiPo Unlocking Potential Report 2.0 - Types: P, A, K, S, B
#
# [133/377] Visiting: https://www.shl.com/products/product-catalog/view/housekeeping-new/
#   ✔ Housekeeping (New) - Types: P, A, K, S, B
#
# [134/377] Visiting: https://www.shl.com/products/product-catalog/view/html5-new/
#   ✔ HTML5 (New) - Types: P, A, K, S, B
#
# [135/377] Visiting: https://www.shl.com/products/product-catalog/view/htmlcss-new/
#   ✔ HTML/CSS (New) - Types: P, A, K, S, B
#
# [136/377] Visiting: https://www.shl.com/products/product-catalog/view/human-resources-new/
#   ✔ Human Resources (New) - Types: P, A, K, S, B
#
# [137/377] Visiting: https://www.shl.com/products/product-catalog/view/ibm-datastage-new/
#   ✔ IBM DataStage (New) - Types: P, A, K, S, B
#
# [138/377] Visiting: https://www.shl.com/products/product-catalog/view/ibm-sterling-order-management-system-new/
#   ✔ IBM Sterling Order Management System (New) - Types: P, A, K, S, B
#
# [139/377] Visiting: https://www.shl.com/products/product-catalog/view/industrial-engineering-new/
#   ✔ Industrial Engineering (New) - Types: P, A, K, S, B
#
# [140/377] Visiting: https://www.shl.com/products/product-catalog/view/informatica-architecture-new/
#   ✔ Informatica (Architecture) (New) - Types: P, A, K, S, B
#
# [141/377] Visiting: https://www.shl.com/products/product-catalog/view/informatica-developer-new/
#   ✔ Informatica (Developer) (New) - Types: P, A, K, S, B
#
# [142/377] Visiting: https://www.shl.com/products/product-catalog/view/instrumentation-engineering-new/
#   ✔ Instrumentation Engineering (New) - Types: P, A, K, S, B
#
# [143/377] Visiting: https://www.shl.com/products/product-catalog/view/interpersonal-communications/
#   ✔ Interpersonal Communications - Types: P, A, K, S, B
#
# [144/377] Visiting: https://www.shl.com/products/product-catalog/view/interviewing-and-hiring-concepts-u-s/
#   ✔ Interviewing and Hiring Concepts (U.S.) - Types: P, A, K, S, B
#
# [145/377] Visiting: https://www.shl.com/products/product-catalog/view/ios-development-new/
#   ✔ iOS Development (New) - Types: P, A, K, S, B
#
# [146/377] Visiting: https://www.shl.com/products/product-catalog/view/itil-it-infrastructure-library-new/
#   ✔ ITIL (IT Infrastructure Library) (New) - Types: P, A, K, S, B
#
# [147/377] Visiting: https://www.shl.com/products/product-catalog/view/java-2-platform-enterprise-edition-1-4-fundamental/
#   ✔ Java 2 Platform Enterprise Edition 1.4 Fundamental - Types: P, A, K, S, B
#
# [148/377] Visiting: https://www.shl.com/products/product-catalog/view/java-8-new/
#   ✔ Java 8 (New) - Types: P, A, K, S, B
#
# [149/377] Visiting: https://www.shl.com/products/product-catalog/view/java-design-patterns-new/
#   ✔ Java Design Patterns (New) - Types: P, A, K, S, B
# [150/377] Visiting: https://www.shl.com/products/product-catalog/view/java-frameworks-new/
#   ✔ Java Frameworks (New) - Types: P, A, K, S, B
#
# [151/377] Visiting: https://www.shl.com/products/product-catalog/view/java-platform-enterprise-edition-7-java-ee-7/
#   ✔ Java Platform Enterprise Edition 7 (Java EE 7) - Types: P, A, K, S, B
#
# [152/377] Visiting: https://www.shl.com/products/product-catalog/view/java-web-services-new/
#   ✔ Java Web Services (New) - Types: P, A, K, S, B
#
# [153/377] Visiting: https://www.shl.com/products/product-catalog/view/javascript-new/
#   ✔ JavaScript (New) - Types: P, A, K, S, B
#
# [154/377] Visiting: https://www.shl.com/products/product-catalog/view/jenkins-new/
#   ✔ Jenkins (New) - Types: P, A, K, S, B
#
# [155/377] Visiting: https://www.shl.com/products/product-catalog/view/job-control-language-new/
#   ✔ Job Control Language (New) - Types: P, A, K, S, B
#
# [156/377] Visiting: https://www.shl.com/products/product-catalog/view/jquery-new/
#   ✔ jQuery (New) - Types: P, A, K, S, B
#
# [157/377] Visiting: https://www.shl.com/products/product-catalog/view/kubernetes-new/
#   ✔ Kubernetes (New) - Types: P, A, K, S, B
#
# [158/377] Visiting: https://www.shl.com/products/product-catalog/view/linux-administration-new/
#   ✔ Linux Administration (New) - Types: P, A, K, S, B
#
# [159/377] Visiting: https://www.shl.com/products/product-catalog/view/linux-operating-system/
#   ✔ Linux Operating System - Types: P, A, K, S, B
#
# [160/377] Visiting: https://www.shl.com/products/product-catalog/view/linux-programming-general/
#   ✔ Linux Programming (General) - Types: P, A, K, S, B
#
# [161/377] Visiting: https://www.shl.com/products/product-catalog/view/load-runner-new/
#   ✔ Load Runner (New) - Types: P, A, K, S, B
#
# [162/377] Visiting: https://www.shl.com/products/product-catalog/view/management-scenarios/
#   ✔ Management Scenarios - Types: P, A, K, S, B
#
# [163/377] Visiting: https://www.shl.com/products/product-catalog/view/managerial-scenarios-candidate-report/
#   ✔ Managerial Scenarios Candidate Report - Types: P, A, K, S, B
#
# [164/377] Visiting: https://www.shl.com/products/product-catalog/view/managerial-scenarios-narrative-report/
#   ✔ Managerial Scenarios Narrative Report - Types: P, A, K, S, B
#
# [165/377] Visiting: https://www.shl.com/products/product-catalog/view/managerial-scenarios-profile-report/
#   ✔ Managerial Scenarios Profile Report - Types: P, A, K, S, B
#
# [166/377] Visiting: https://www.shl.com/products/product-catalog/view/manual-testing-new/
#   ✔ Manual Testing (New) - Types: P, A, K, S, B
#
# [167/377] Visiting: https://www.shl.com/products/product-catalog/view/marketing-new/
#   ✔ Marketing (New) - Types: P, A, K, S, B
#
# [168/377] Visiting: https://www.shl.com/products/product-catalog/view/maven-new/
#   ✔ Maven (New) - Types: P, A, K, S, B
#
# [169/377] Visiting: https://www.shl.com/products/product-catalog/view/mechanical-and-vigilance-focus-8-0/
#   ✔ Manufac. & Indust. - Mechanical & Vigilance 8.0 - Types: P, A, K, S, B
#
# [170/377] Visiting: https://www.shl.com/products/product-catalog/view/mechanical-engineering-new/
#   ✔ Mechanical Engineering (New) - Types: P, A, K, S, B
#
# [171/377] Visiting: https://www.shl.com/products/product-catalog/view/mechanical-focus-8-0/
#   ✔ Manufacturing & Industrial - Mechanical Focus 8.0 - Types: P, A, K, S, B
#
# [172/377] Visiting: https://www.shl.com/products/product-catalog/view/mechatronics-engineering-new/
#   ✔ Mechatronics Engineering (New) - Types: P, A, K, S, B
#
# [173/377] Visiting: https://www.shl.com/products/product-catalog/view/medical-terminology-new/
#   ✔ Medical Terminology (New) - Types: P, A, K, S, B
#
# [174/377] Visiting: https://www.shl.com/products/product-catalog/view/metallurgical-engineering-new/
#   ✔ Metallurgical Engineering (New) - Types: P, A, K, S, B
#
# [175/377] Visiting: https://www.shl.com/products/product-catalog/view/mfs-360-enterprise-leadership-report/
#   ✔ MFS 360 Enterprise Leadership Report - Types: P, A, K, S, B
#
# [176/377] Visiting: https://www.shl.com/products/product-catalog/view/mfs-360-ucf-group-report/
#   ✔ MFS 360 UCF Group Report - Types: P, A, K, S, B
#
# [177/377] Visiting: https://www.shl.com/products/product-catalog/view/mfs-360-ucf-performance-potential-dev-tips-report/
#   ✔ MFS 360 UCF Performance Potential Dev Tips Report - Types: P, A, K, S, B
#
# [178/377] Visiting: https://www.shl.com/products/product-catalog/view/mfs-360-ucf-standard-report/
#   ✔ MFS 360 UCF Standard Report - Types: P, A, K, S, B
#
# [179/377] Visiting: https://www.shl.com/products/product-catalog/view/micro-focus-unified-functional-testing-new/
#   ✔ Micro Focus Unified Functional Testing (New) - Types: P, A, K, S, B
#
# [180/377] Visiting: https://www.shl.com/products/product-catalog/view/microservices-new/
#   ✔ Microservices (New) - Types: P, A, K, S, B
#
# [181/377] Visiting: https://www.shl.com/products/product-catalog/view/microsoft-dynamics-development-new/
#   ✔ Microsoft Dynamics Development (New) - Types: P, A, K, S, B
#
# [182/377] Visiting: https://www.shl.com/products/product-catalog/view/microsoft-excel-365-essentials-new/
#   ✔ Microsoft Excel 365 - Essentials (New) - Types: P, A, K, S, B
#
# [183/377] Visiting: https://www.shl.com/products/product-catalog/view/microsoft-excel-365-new/
#   ✔ Microsoft Excel 365 (New) - Types: P, A, K, S, B
#
# [184/377] Visiting: https://www.shl.com/products/product-catalog/view/microsoft-outlook-2013-adaptive/
#   ✔ Microsoft Outlook 2013 (adaptive) - Types: P, A, K, S, B
#
# [185/377] Visiting: https://www.shl.com/products/product-catalog/view/microsoft-powerpoint-365-essentials-new/
#   ✔ Microsoft PowerPoint 365 - Essentials (New) - Types: P, A, K, S, B
#
# [186/377] Visiting: https://www.shl.com/products/product-catalog/view/microsoft-sql-server-2014-programming/
#   ✔ Microsoft SQL Server 2014 Programming - Types: P, A, K, S, B
#
# [187/377] Visiting: https://www.shl.com/products/product-catalog/view/microsoft-windows-server-2012-administration/
#   ✔ Microsoft Windows Server 2012 Administration - Types: P, A, K, S, B
#
# [188/377] Visiting: https://www.shl.com/products/product-catalog/view/microsoft-word-365-essentials-new/
#   ✔ Microsoft Word 365 - Essentials (New) - Types: P, A, K, S, B
#
# [189/377] Visiting: https://www.shl.com/products/product-catalog/view/microsoft-word-365-new/
#   ✔ Microsoft Word 365 (New) - Types: P, A, K, S, B
#
# [190/377] Visiting: https://www.shl.com/products/product-catalog/view/mineral-engineering-new/
#   ✔ Mineral Engineering (New) - Types: P, A, K, S, B
#
# [191/377] Visiting: https://www.shl.com/products/product-catalog/view/mining-engineering-new/
#   ✔ Mining Engineering (New) - Types: P, A, K, S, B
#
# [192/377] Visiting: https://www.shl.com/products/product-catalog/view/mobility-new/
#   ✔ Mobility (New) - Types: P, A, K, S, B
#
# [193/377] Visiting: https://www.shl.com/products/product-catalog/view/molecular-biology-new/
#   ✔ Molecular Biology (New) - Types: P, A, K, S, B
#
# [194/377] Visiting: https://www.shl.com/products/product-catalog/view/mongodb-new/
#   ✔ MongoDB (New) - Types: P, A, K, S, B
#
# [195/377] Visiting: https://www.shl.com/products/product-catalog/view/motivation-questionnaire-mqm5/
#   ✔ Motivation Questionnaire MQM5 - Types: P, A, K, S, B
#
# [196/377] Visiting: https://www.shl.com/products/product-catalog/view/mq-candidate-motivation-report/
#   ✔ MQ Candidate Motivation Report - Types: P, A, K, S, B
#
# [197/377] Visiting: https://www.shl.com/products/product-catalog/view/mq-employee-motivation-report/
#   ✔ MQ Employee Motivation Report - Types: P, A, K, S, B
#
# [198/377] Visiting: https://www.shl.com/products/product-catalog/view/mq-motivation-report-pack/
#   ✔ MQ Motivation Report Pack - Types: P, A, K, S, B
#
# [199/377] Visiting: https://www.shl.com/products/product-catalog/view/mq-profile/
#   ✔ MQ Profile - Types: P, A, K, S, B
#
# [200/377] Visiting: https://www.shl.com/products/product-catalog/view/ms-access-new/
#   ✔ MS Access (New) - Types: P, A, K, S, B
#
# [201/377] Visiting: https://www.shl.com/products/product-catalog/view/ms-excel-new/
#   ✔ MS Excel (New) - Types: P, A, K, S, B
#
# [202/377] Visiting: https://www.shl.com/products/product-catalog/view/ms-office-basic-computer-literacy-new/
#   ✔ MS Office Basic Computer Literacy (New) - Types: P, A, K, S, B
#
# [203/377] Visiting: https://www.shl.com/products/product-catalog/view/ms-office-basic-computer-literacy-sim-new/
#   ✔ MS Office Basic Computer Literacy (Sim) (New) - Types: P, A, K, S, B
#
# [204/377] Visiting: https://www.shl.com/products/product-catalog/view/ms-powerpoint-new/
#   ✔ MS PowerPoint (New) - Types: P, A, K, S, B
#
# [205/377] Visiting: https://www.shl.com/products/product-catalog/view/ms-word-new/
#   ✔ MS Word (New) - Types: P, A, K, S, B
#
# [206/377] Visiting: https://www.shl.com/products/product-catalog/view/mulesoft-development-new/
#   ✔ MuleSoft Development (New) - Types: P, A, K, S, B
#
# [207/377] Visiting: https://www.shl.com/products/product-catalog/view/multitasking-ability/
#   ✔ Multitasking Ability - Types: P, A, K, S, B
#
# [208/377] Visiting: https://www.shl.com/products/product-catalog/view/net-framework-4-5/
#   ✔ .NET Framework 4.5 - Types: P, A, K, S, B
#
# [209/377] Visiting: https://www.shl.com/products/product-catalog/view/net-mvc-new/
#   ✔ .NET MVC (New) - Types: P, A, K, S, B
#
# [210/377] Visiting: https://www.shl.com/products/product-catalog/view/net-mvvm-new/
#   ✔ .NET MVVM (New) - Types: P, A, K, S, B
#
# [211/377] Visiting: https://www.shl.com/products/product-catalog/view/net-wcf-new/
#   ✔ .NET WCF (New) - Types: P, A, K, S, B
#
# [212/377] Visiting: https://www.shl.com/products/product-catalog/view/net-wpf-new/
#   ✔ .NET WPF (New) - Types: P, A, K, S, B
#
# [213/377] Visiting: https://www.shl.com/products/product-catalog/view/net-xaml-new/
#   ✔ .NET XAML (New) - Types: P, A, K, S, B
#
# [214/377] Visiting: https://www.shl.com/products/product-catalog/view/networking-and-implementation-new/
#   ✔ Networking and Implementation (New) - Types: P, A, K, S, B
#
# [215/377] Visiting: https://www.shl.com/products/product-catalog/view/node-js-new/
#   ✔ Node.js (New) - Types: P, A, K, S, B
#
# [216/377] Visiting: https://www.shl.com/products/product-catalog/view/nursing-new/
#   ✔ Nursing (New) - Types: P, A, K, S, B
#
# [217/377] Visiting: https://www.shl.com/products/product-catalog/view/occupational-personality-questionnaire-opq32r/
#   ✔ Occupational Personality Questionnaire OPQ32r - Types: P, A, K, S, B
#
# [218/377] Visiting: https://www.shl.com/products/product-catalog/view/operations-management-new/
#   ✔ Operations Management (New) - Types: P, A, K, S, B
#
# [219/377] Visiting: https://www.shl.com/products/product-catalog/view/opq-candidate-plus-report/
#   ✔ OPQ Candidate Plus Report - Types: P, A, K, S, B
#
# [220/377] Visiting: https://www.shl.com/products/product-catalog/view/opq-candidate-report-2-0/
#   ✔ OPQ Candidate Report 2.0 - Types: P, A, K, S, B
#
# [221/377] Visiting: https://www.shl.com/products/product-catalog/view/opq-emotional-intelligence-report/
#   ✔ OPQ Emotional Intelligence Report - Types: P, A, K, S, B
#
# [222/377] Visiting: https://www.shl.com/products/product-catalog/view/opq-leadership-report/
#   ✔ OPQ Leadership Report - Types: P, A, K, S, B
#
# [223/377] Visiting: https://www.shl.com/products/product-catalog/view/opq-manager-plus-report-2-0/
#   ✔ OPQ Manager Plus Report 2.0 - Types: P, A, K, S, B
#
# [224/377] Visiting: https://www.shl.com/products/product-catalog/view/opq-manager-plus-report/
#   ✔ OPQ Manager Plus Report - Types: P, A, K, S, B
#
# [225/377] Visiting: https://www.shl.com/products/product-catalog/view/opq-maximising-your-learning-report/
#   ✔ OPQ Maximising your Learning Report - Types: P, A, K, S, B
#
# [226/377] Visiting: https://www.shl.com/products/product-catalog/view/opq-mq-sales-report/
#   ✔ OPQ MQ Sales Report - Types: P, A, K, S, B
#
# [227/377] Visiting: https://www.shl.com/products/product-catalog/view/opq-premium-plus-report-2-0/
#   ✔ OPQ Premium Plus Report 2.0 - Types: P, A, K, S, B
#
# [228/377] Visiting: https://www.shl.com/products/product-catalog/view/opq-premium-plus-report/
#   ✔ OPQ Premium Plus Report - Types: P, A, K, S, B
#
# [229/377] Visiting: https://www.shl.com/products/product-catalog/view/opq-profile-report/
#   ✔ OPQ Profile Report - Types: P, A, K, S, B
# [230/377] Visiting: https://www.shl.com/products/product-catalog/view/opq-team-impact-group-development-report/
#   ✔ OPQ Team Impact Group Development Report - Types: P, A, K, S, B
#
# [231/377] Visiting: https://www.shl.com/products/product-catalog/view/opq-team-impact-individual-development-report/
#   ✔ OPQ Team Impact Individual Development Report - Types: P, A, K, S, B
#
# [232/377] Visiting: https://www.shl.com/products/product-catalog/view/opq-team-impact-selection-report/
#   ✔ OPQ Team Impact Selection Report - Types: P, A, K, S, B
#
# [233/377] Visiting: https://www.shl.com/products/product-catalog/view/opq-team-types-and-leadership-styles-profile/
#   ✔ OPQ Team Types & Leadership Styles Profile - Types: P, A, K, S, B
#
# [234/377] Visiting: https://www.shl.com/products/product-catalog/view/opq-team-types-and-leadership-styles-report/
#   ✔ OPQ Team Types and Leadership Styles Report - Types: P, A, K, S, B
#
# [235/377] Visiting: https://www.shl.com/products/product-catalog/view/opq-ucf-development-action-planner-report-2-0/
#   ✔ OPQ UCF Development Action Planner Report 2.0 - Types: P, A, K, S, B
#
# [236/377] Visiting: https://www.shl.com/products/product-catalog/view/opq-ucf-development-action-planner-report/
#   ✔ OPQ UCF Development Action Planner Report 1.0 - Types: P, A, K, S, B
#
# [237/377] Visiting: https://www.shl.com/products/product-catalog/view/opq-universal-competency-report-2-0/
#   ✔ OPQ Universal Competency Report 2.0 - Types: P, A, K, S, B
#
# [238/377] Visiting: https://www.shl.com/products/product-catalog/view/opq-universal-competency-report/
#   ✔ OPQ Universal Competency Report 1.0 - Types: P, A, K, S, B
#
# [239/377] Visiting: https://www.shl.com/products/product-catalog/view/opq-user-and-managers-report/
#   ✔ OPQ User and Managers Report - Types: P, A, K, S, B
#
# [240/377] Visiting: https://www.shl.com/products/product-catalog/view/opq-user-report/
#   ✔ OPQ User Report - Types: P, A, K, S, B
#
# [241/377] Visiting: https://www.shl.com/products/product-catalog/view/oracle-dba-advanced-level-new/
#   ✔ Oracle DBA (Advanced Level) (New) - Types: P, A, K, S, B
#
# [242/377] Visiting: https://www.shl.com/products/product-catalog/view/oracle-dba-entry-level-new/
#   ✔ Oracle DBA (Entry Level) (New) - Types: P, A, K, S, B
#
# [243/377] Visiting: https://www.shl.com/products/product-catalog/view/oracle-plsql-new/
#   ✔ Oracle PL/SQL (New) - Types: P, A, K, S, B
#
# [244/377] Visiting: https://www.shl.com/products/product-catalog/view/oracle-weblogic-server-new/
#   ✔ Oracle WebLogic Server (New) - Types: P, A, K, S, B
#
# [245/377] Visiting: https://www.shl.com/products/product-catalog/view/organic-chemistry-new/
#   ✔ Organic Chemistry (New) - Types: P, A, K, S, B
#
# [246/377] Visiting: https://www.shl.com/products/product-catalog/view/paint-technology-new/
#   ✔ Paint Technology (New) - Types: P, A, K, S, B
#
# [247/377] Visiting: https://www.shl.com/products/product-catalog/view/pediatrics-new/
#   ✔ Pediatrics (New) - Types: P, A, K, S, B
#
# [248/377] Visiting: https://www.shl.com/products/product-catalog/view/pega-development-new/
#   ✔ Pega Development (New) - Types: P, A, K, S, B
#
# [249/377] Visiting: https://www.shl.com/products/product-catalog/view/perl-new/
#   ✔ Perl (New) - Types: P, A, K, S, B
#
# [250/377] Visiting: https://www.shl.com/products/product-catalog/view/petrochemical-engineering-new/
#   ✔ Petrochemical Engineering (New) - Types: P, A, K, S, B
#
# [251/377] Visiting: https://www.shl.com/products/product-catalog/view/petroleum-engineering-new/
#   ✔ Petroleum Engineering (New) - Types: P, A, K, S, B
#
# [252/377] Visiting: https://www.shl.com/products/product-catalog/view/pharmaceutical-analysis-new/
#   ✔ Pharmaceutical Analysis (New) - Types: P, A, K, S, B
#
# [253/377] Visiting: https://www.shl.com/products/product-catalog/view/pharmaceutical-chemistry-new/
#   ✔ Pharmaceutical Chemistry (New) - Types: P, A, K, S, B
#
# [254/377] Visiting: https://www.shl.com/products/product-catalog/view/pharmaceutical-science-new/
#   ✔ Pharmaceutical Science (New) - Types: P, A, K, S, B
#
# [255/377] Visiting: https://www.shl.com/products/product-catalog/view/pharmaceutics-new/
#   ✔ Pharmaceutics (New) - Types: P, A, K, S, B
#
# [256/377] Visiting: https://www.shl.com/products/product-catalog/view/pharmacology-new/
#   ✔ Pharmacology (New) - Types: P, A, K, S, B
#
# [257/377] Visiting: https://www.shl.com/products/product-catalog/view/php-new/
#   ✔ PHP (New) - Types: P, A, K, S, B
#
# [258/377] Visiting: https://www.shl.com/products/product-catalog/view/pjm-development-report/
#   ✔ PJM Development Report - Types: P, A, K, S, B
#
# [259/377] Visiting: https://www.shl.com/products/product-catalog/view/pjm-selection-report/
#   ✔ PJM Selection Report - Types: P, A, K, S, B
#
# [260/377] Visiting: https://www.shl.com/products/product-catalog/view/polymer-engineering-new/
#   ✔ Polymer Engineering (New) - Types: P, A, K, S, B
#
# [261/377] Visiting: https://www.shl.com/products/product-catalog/view/power-electronics-and-drives-new/
#   ✔ Power Electronics and Drives (New) - Types: P, A, K, S, B
#
# [262/377] Visiting: https://www.shl.com/products/product-catalog/view/power-system-engineering-new/
#   ✔ Power System Engineering (New) - Types: P, A, K, S, B
#
# [263/377] Visiting: https://www.shl.com/products/product-catalog/view/prism-new/
#   ✔ Prism (New) - Types: P, A, K, S, B
#
# [264/377] Visiting: https://www.shl.com/products/product-catalog/view/production-and-industrial-engineering-new/
#   ✔ Production and Industrial Engineering (New) - Types: P, A, K, S, B
#
# [265/377] Visiting: https://www.shl.com/products/product-catalog/view/production-engineering-new/
#   ✔ Production Engineering (New) - Types: P, A, K, S, B
#
# [266/377] Visiting: https://www.shl.com/products/product-catalog/view/programming-concepts/
#   ✔ Programming Concepts - Types: P, A, K, S, B
#
# [267/377] Visiting: https://www.shl.com/products/product-catalog/view/project-management-2013/
#   ✔ Project Management (2013) - Types: P, A, K, S, B
#
# [268/377] Visiting: https://www.shl.com/products/product-catalog/view/proofreading-v1/
#   ✔ Proofreading v1 - Types: P, A, K, S, B
#
# [269/377] Visiting: https://www.shl.com/products/product-catalog/view/python-new/
#   ✔ Python (New) - Types: P, A, K, S, B
#
# [270/377] Visiting: https://www.shl.com/products/product-catalog/view/r-programming-new/
#   ✔ R Programming (New) - Types: P, A, K, S, B
#
# [271/377] Visiting: https://www.shl.com/products/product-catalog/view/reactjs-new/
#   ✔ ReactJS (New) - Types: P, A, K, S, B
#
# [272/377] Visiting: https://www.shl.com/products/product-catalog/view/reading-comprehension-english-v1/
#   ✔ Reading Comprehension - English v1 - Types: P, A, K, S, B
#
# [273/377] Visiting: https://www.shl.com/products/product-catalog/view/reading-comprehension-spanish-v1/
#   ✔ Reading Comprehension - Spanish v1 - Types: P, A, K, S, B
#
# [274/377] Visiting: https://www.shl.com/products/product-catalog/view/reading-comprehension-v2/
#   ✔ Reading Comprehension v2 - Types: P, A, K, S, B
#
# [275/377] Visiting: https://www.shl.com/products/product-catalog/view/remoteworkq-manager-report/
#   ✔ RemoteWorkQ Manager Report - Types: P, A, K, S, B
#
# [276/377] Visiting: https://www.shl.com/products/product-catalog/view/remoteworkq-participant-report/
#   ✔ RemoteWorkQ Participant Report - Types: P, A, K, S, B
#
# [277/377] Visiting: https://www.shl.com/products/product-catalog/view/remoteworkq/
#   ✔ RemoteWorkQ - Types: P, A, K, S, B
#
# [278/377] Visiting: https://www.shl.com/products/product-catalog/view/restful-web-services-new/
#   ✔ RESTful Web Services (New) - Types: P, A, K, S, B
#
# [279/377] Visiting: https://www.shl.com/products/product-catalog/view/retail-sales-and-service-simulation/
#   ✔ Retail Sales and Service Simulation - Types: P, A, K, S, B
#
# [280/377] Visiting: https://www.shl.com/products/product-catalog/view/reviewing-forms-us-r1/
#   ✔ Reviewing Forms - US (R1) - Types: P, A, K, S, B
#
# [281/377] Visiting: https://www.shl.com/products/product-catalog/view/ruby-new/
#   ✔ Ruby (New) - Types: P, A, K, S, B
#
# [282/377] Visiting: https://www.shl.com/products/product-catalog/view/ruby-on-rails-new/
#   ✔ Ruby on Rails (New) - Types: P, A, K, S, B
#
# [283/377] Visiting: https://www.shl.com/products/product-catalog/view/safety-and-dependability-focus-8-0/
#   ✔ Manufac. & Indust. - Safety & Dependability 8.0 - Types: P, A, K, S, B
#
# [284/377] Visiting: https://www.shl.com/products/product-catalog/view/sales-and-service-phone-simulation/
#   ✔ Sales & Service Phone Simulation - Types: P, A, K, S, B
#
# [285/377] Visiting: https://www.shl.com/products/product-catalog/view/sales-and-service-phone-solution/
#   ✔ Sales & Service Phone Solution - Types: P, A, K, S, B
#
# [286/377] Visiting: https://www.shl.com/products/product-catalog/view/sales-interview-guide/
#   ✔ Sales Interview Guide - Types: P, A, K, S, B
#
# [287/377] Visiting: https://www.shl.com/products/product-catalog/view/sales-profiler-cards/
#   ✔ Sales Profiler Cards - Types: P, A, K, S, B
#
# [288/377] Visiting: https://www.shl.com/products/product-catalog/view/sales-transformation-report-2-0-sales-manager/
#   ✔ Sales Transformation Report 2.0 - Sales Manager - Types: P, A, K, S, B
#
# [289/377] Visiting: https://www.shl.com/products/product-catalog/view/sales-transformation-report-individual-contributor/
#   ✔ Sales Transformation 1.0 - Individual Contributor - Types: P, A, K, S, B
#
# [290/377] Visiting: https://www.shl.com/products/product-catalog/view/sales-transformation-report-sales-manager/
#   ✔ Sales Transformation Report 1.0 - Sales Manager - Types: P, A, K, S, B
#
# [291/377] Visiting: https://www.shl.com/products/product-catalog/view/salesforce-development-new/
#   ✔ Salesforce Development (New) - Types: P, A, K, S, B
#
# [292/377] Visiting: https://www.shl.com/products/product-catalog/view/salestransformationreport2-0-individualcontributor/
#   ✔ Sales Transformation 2.0 - Individual Contributor - Types: P, A, K, S, B
#
# [293/377] Visiting: https://www.shl.com/products/product-catalog/view/sap-abap-advanced-level-new/
#   ✔ SAP ABAP (Advanced Level) (New) - Types: P, A, K, S, B
#
# [294/377] Visiting: https://www.shl.com/products/product-catalog/view/sap-abap-intermediate-level-new/
#   ✔ SAP ABAP (Intermediate Level) (New) - Types: P, A, K, S, B
#
# [295/377] Visiting: https://www.shl.com/products/product-catalog/view/sap-basis-new/
#   ✔ SAP Basis (New) - Types: P, A, K, S, B
#
# [296/377] Visiting: https://www.shl.com/products/product-catalog/view/sap-business-objects-webi-new/
#   ✔ SAP Business Objects WebI (New) - Types: P, A, K, S, B
#
# [297/377] Visiting: https://www.shl.com/products/product-catalog/view/sap-bw-business-warehouse-new/
#   ✔ SAP BW (Business Warehouse) (New) - Types: P, A, K, S, B
#
# [298/377] Visiting: https://www.shl.com/products/product-catalog/view/sap-hcm-human-capital-management-new/
#   ✔ SAP HCM (Human Capital Management) (New) - Types: P, A, K, S, B
#
# [299/377] Visiting: https://www.shl.com/products/product-catalog/view/sap-hybris-new/
#   ✔ SAP Hybris (New) - Types: P, A, K, S, B
#
# [300/377] Visiting: https://www.shl.com/products/product-catalog/view/sap-materials-management-new/
#   ✔ SAP Materials Management (New) - Types: P, A, K, S, B
#
# [301/377] Visiting: https://www.shl.com/products/product-catalog/view/sap-sd-sales-and-distribution-new/
#   ✔ SAP SD (Sales and Distribution) (New) - Types: P, A, K, S, B
#
# [302/377] Visiting: https://www.shl.com/products/product-catalog/view/search-engine-optimization-new/
#   ✔ Search Engine Optimization (New) - Types: P, A, K, S, B
#
# [303/377] Visiting: https://www.shl.com/products/product-catalog/view/selenium-new/
#   ✔ Selenium (New) - Types: P, A, K, S, B
#
# [304/377] Visiting: https://www.shl.com/products/product-catalog/view/shell-scripting-new/
#   ✔ Shell Scripting (New) - Types: P, A, K, S, B
#
# [305/377] Visiting: https://www.shl.com/products/product-catalog/view/shl-verify-interactive-deductive-reasoning/
#   ✔ SHL Verify Interactive – Deductive Reasoning - Types: P, A, K, S, B
#
# [306/377] Visiting: https://www.shl.com/products/product-catalog/view/shl-verify-interactive-g/
#   ✔ SHL Verify Interactive G+ - Types: P, A, K, S, B
#
# [307/377] Visiting: https://www.shl.com/products/product-catalog/view/shl-verify-interactive-inductive-reasoning/
#   ✔ SHL Verify Interactive - Inductive Reasoning - Types: P, A, K, S, B
#
# [308/377] Visiting: https://www.shl.com/products/product-catalog/view/shl-verify-interactive-numerical-calculation/
#   ✔ SHL Verify Interactive Numerical Calculation - Types: P, A, K, S, B
#
# [309/377] Visiting: https://www.shl.com/products/product-catalog/view/shl-verify-interactive-numerical-reasoning/
#   ✔ SHL Verify Interactive – Numerical Reasoning - Types: P, A, K, S, B
#
# [310/377] Visiting: https://www.shl.com/products/product-catalog/view/siebel-development-new/
#   ✔ Siebel Development (New) - Types: P, A, K, S, B
#
# [311/377] Visiting: https://www.shl.com/products/product-catalog/view/smart-interview-live-coding/
#   ✔ Smart Interview Live Coding - Types: P, A, K, S, B
#
# [312/377] Visiting: https://www.shl.com/products/product-catalog/view/smart-interview-live/
#   ✔ Smart Interview Live - Types: P, A, K, S, B
#
# [313/377] Visiting: https://www.shl.com/products/product-catalog/view/smart-interview-on-demand/
#   ✔ Smart Interview On Demand - Types: P, A, K, S, B
#
# [314/377] Visiting: https://www.shl.com/products/product-catalog/view/social-media-new/
#   ✔ Social Media (New) - Types: P, A, K, S, B
#
# [315/377] Visiting: https://www.shl.com/products/product-catalog/view/software-business-analysis/
#   ✔ Software Business Analysis - Types: P, A, K, S, B
#
# [316/377] Visiting: https://www.shl.com/products/product-catalog/view/sonarqube-new/
#   ✔ SonarQube (New) - Types: P, A, K, S, B
#
# [317/377] Visiting: https://www.shl.com/products/product-catalog/view/spelling-u-s-new/
#   ✔ Spelling (U.S.) (New) - Types: P, A, K, S, B
#
# [318/377] Visiting: https://www.shl.com/products/product-catalog/view/split-screen-typing-test-form-1/
#   ✔ Split Screen Typing Test - Form 1 - Types: P, A, K, S, B
#
# [319/377] Visiting: https://www.shl.com/products/product-catalog/view/spring-new/
#   ✔ Spring (New) - Types: P, A, K, S, B
#
# [320/377] Visiting: https://www.shl.com/products/product-catalog/view/sql-new/
#   ✔ SQL (New) - Types: P, A, K, S, B
#
# [321/377] Visiting: https://www.shl.com/products/product-catalog/view/sql-server-analysis-services-%28ssas%29-%28new%29/
#   ✔ SQL Server Analysis Services (SSAS) (New) - Types: P, A, K, S, B
#
# [322/377] Visiting: https://www.shl.com/products/product-catalog/view/sql-server-integration-services-ssis-new/
#   ✔ SQL Server Integration Services (SSIS) (New) - Types: P, A, K, S, B
#
# [323/377] Visiting: https://www.shl.com/products/product-catalog/view/sql-server-new/
#   ✔ SQL Server (New) - Types: P, A, K, S, B
#
# [324/377] Visiting: https://www.shl.com/products/product-catalog/view/sql-server-reporting-services-ssrs-new/
#   ✔ SQL Server Reporting Services (SSRS) (New) - Types: P, A, K, S, B
#
# [325/377] Visiting: https://www.shl.com/products/product-catalog/view/statistical-analysis-system-new/
#   ✔ Statistical Analysis System (New) - Types: P, A, K, S, B
#
# [326/377] Visiting: https://www.shl.com/products/product-catalog/view/struts-new/
#   ✔ Struts (New) - Types: P, A, K, S, B
#
# [327/377] Visiting: https://www.shl.com/products/product-catalog/view/svar-spoken-english-aus/
#   ✔ SVAR - Spoken English (AUS) - Types: P, A, K, S, B
#
# [328/377] Visiting: https://www.shl.com/products/product-catalog/view/svar-spoken-english-indian-accent-new/
#   ✔ SVAR - Spoken English (Indian Accent) (New) - Types: P, A, K, S, B
#
# [329/377] Visiting: https://www.shl.com/products/product-catalog/view/svar-spoken-english-u-k/
#   ✔ SVAR - Spoken English (U.K.) - Types: P, A, K, S, B
#
# [330/377] Visiting: https://www.shl.com/products/product-catalog/view/svar-spoken-english-us-new/
#   ✔ SVAR - Spoken English (US) (New) - Types: P, A, K, S, B
#
# [331/377] Visiting: https://www.shl.com/products/product-catalog/view/svar-spoken-french-canadian-new/
#   ✔ SVAR - Spoken French (Canadian) (New) - Types: P, A, K, S, B
#
# [332/377] Visiting: https://www.shl.com/products/product-catalog/view/svar-spoken-french-european-new/
#   ✔ SVAR - Spoken French (European) (New) - Types: P, A, K, S, B
#
# [333/377] Visiting: https://www.shl.com/products/product-catalog/view/svar-spoken-spanish-castilian-new/
#   ✔ SVAR - Spoken Spanish (Castilian) (New) - Types: P, A, K, S, B
#
# [334/377] Visiting: https://www.shl.com/products/product-catalog/view/svar-spoken-spanish-north-american-new/
#   ✔ SVAR - Spoken Spanish (North American) (New) - Types: P, A, K, S, B
#
# [335/377] Visiting: https://www.shl.com/products/product-catalog/view/swing-new/
#   ✔ Swing (New) - Types: P, A, K, S, B
#
# [336/377] Visiting: https://www.shl.com/products/product-catalog/view/tableau-new/
#   ✔ Tableau (New) - Types: P, A, K, S, B
#
# [337/377] Visiting: https://www.shl.com/products/product-catalog/view/telecommunications-engineering-new/
#   ✔ Telecommunications Engineering (New) - Types: P, A, K, S, B
#
# [338/377] Visiting: https://www.shl.com/products/product-catalog/view/teradata-development-new/
#   ✔ Teradata Development (New) - Types: P, A, K, S, B
#
# [339/377] Visiting: https://www.shl.com/products/product-catalog/view/time-management-u-s/
#   ✔ Time Management (U.S.) - Types: P, A, K, S, B
#
# [340/377] Visiting: https://www.shl.com/products/product-catalog/view/training-development/
#   ✔ Training Development - Types: P, A, K, S, B
#
# [341/377] Visiting: https://www.shl.com/products/product-catalog/view/typing-new/
#   ✔ Typing (New) - Types: P, A, K, S, B
#
# [342/377] Visiting: https://www.shl.com/products/product-catalog/view/uipath-rpa-development-new/
#   ✔ UiPath RPA Development (New) - Types: P, A, K, S, B
#
# [343/377] Visiting: https://www.shl.com/products/product-catalog/view/universal-competency-framework-interview-guide/
#   ✔ Universal Competency Framework Interview Guide - Types: P, A, K, S, B
#
# [344/377] Visiting: https://www.shl.com/products/product-catalog/view/universal-competency-framework-job-profiling-guide/
#   ✔ Universal Competency Framework Job profiling guide - Types: P, A, K, S, B
#
# [345/377] Visiting: https://www.shl.com/products/product-catalog/view/universal-competency-framework-profiler-cards-44/
#   ✔ Universal Competency Framework Profiler Cards (44) - Types: P, A, K, S, B
#
# [346/377] Visiting: https://www.shl.com/products/product-catalog/view/unix-new/
#   ✔ UNIX (New) - Types: P, A, K, S, B
#
# [347/377] Visiting: https://www.shl.com/products/product-catalog/view/vb-net-new/
#   ✔ VB.NET (New) - Types: P, A, K, S, B
#
# [348/377] Visiting: https://www.shl.com/products/product-catalog/view/verify-deductive-reasoning/
#   ✔ Verify - Deductive Reasoning - Types: P, A, K, S, B
#
# [349/377] Visiting: https://www.shl.com/products/product-catalog/view/verify-following-instructions/
#   ✔ Verify - Following Instructions - Types: P, A, K, S, B
#
# [350/377] Visiting: https://www.shl.com/products/product-catalog/view/verify-g-ability-test-report/
#   ✔ Verify G+ - Ability Test Report - Types: P, A, K, S, B
#
# [351/377] Visiting: https://www.shl.com/products/product-catalog/view/verify-g-candidate-report/
#   ✔ Verify G+ - Candidate Report - Types: P, A, K, S, B
#
# [352/377] Visiting: https://www.shl.com/products/product-catalog/view/verify-g/
#   ✔ Verify - G+ - Types: P, A, K, S, B
#
# [353/377] Visiting: https://www.shl.com/products/product-catalog/view/verify-general-ability-screen/
#   ✔ Verify - General Ability Screen - Types: P, A, K, S, B
#
# [354/377] Visiting: https://www.shl.com/products/product-catalog/view/verify-inductive-reasoning-2014/
#   ✔ Verify - Inductive Reasoning (2014) - Types: P, A, K, S, B
#
# [355/377] Visiting: https://www.shl.com/products/product-catalog/view/verify-interactive-ability-report/
#   ✔ Verify Interactive Ability Report - Types: P, A, K, S, B
#
# [356/377] Visiting: https://www.shl.com/products/product-catalog/view/verify-interactive-g-candidate-report/
#   ✔ Verify Interactive G+ Candidate Report - Types: P, A, K, S, B
#
# [357/377] Visiting: https://www.shl.com/products/product-catalog/view/verify-interactive-g-report/
#   ✔ Verify Interactive G+ Report - Types: P, A, K, S, B
#
# [358/377] Visiting: https://www.shl.com/products/product-catalog/view/verify-interactive-process-monitoring/
#   ✔ Verify Interactive Process Monitoring - Types: P, A, K, S, B
#
# [359/377] Visiting: https://www.shl.com/products/product-catalog/view/verify-numerical-ability/
#   ✔ Verify - Numerical Ability - Types: P, A, K, S, B
#
# [360/377] Visiting: https://www.shl.com/products/product-catalog/view/verify-technical-checking-next-generation/
#   ✔ Verify - Technical Checking - Next Generation - Types: P, A, K, S, B
#
# [361/377] Visiting: https://www.shl.com/products/product-catalog/view/verify-verbal-ability-next-generation/
#   ✔ Verify - Verbal Ability - Next Generation - Types: P, A, K, S, B
#
# [362/377] Visiting: https://www.shl.com/products/product-catalog/view/verify-working-with-information/
#   ✔ Verify - Working with Information - Types: P, A, K, S, B
#
# [363/377] Visiting: https://www.shl.com/products/product-catalog/view/vigilance-focus-8-0/
#   ✔ Manufacturing & Industrial - Vigilance Focus 8.0 - Types: P, A, K, S, B
#
# [364/377] Visiting: https://www.shl.com/products/product-catalog/view/virtual-assessment-and-development-centers/
#   ✔ Virtual Assessment and Development Centers - Types: P, A, K, S, B
#
# [365/377] Visiting: https://www.shl.com/products/product-catalog/view/visual-basic-for-applications-new/
#   ✔ Visual Basic for Applications (New) - Types: P, A, K, S, B
#
# [366/377] Visiting: https://www.shl.com/products/product-catalog/view/visual-comparison-uk/
#   ✔ Visual Comparison - UK - Types: P, A, K, S, B
#
# [367/377] Visiting: https://www.shl.com/products/product-catalog/view/visual-comparison-us/
#   ✔ Visual Comparison - US - Types: P, A, K, S, B
#
# [368/377] Visiting: https://www.shl.com/products/product-catalog/view/vlsi-and-embedded-systems-new/
#   ✔ VLSI and Embedded Systems (New) - Types: P, A, K, S, B
#
# [369/377] Visiting: https://www.shl.com/products/product-catalog/view/what-is-the-value-us/
#   ✔ What Is The Value - US - Types: P, A, K, S, B
#
# [370/377] Visiting: https://www.shl.com/products/product-catalog/view/workplace-administration-skills-new/
#   ✔ Workplace Administration Skills (New) - Types: P, A, K, S, B
#
# [371/377] Visiting: https://www.shl.com/products/product-catalog/view/workplace-health-and-safety-new/
#   ✔ Workplace Health and Safety (New) - Types: P, A, K, S, B
#
# [372/377] Visiting: https://www.shl.com/products/product-catalog/view/writex-email-writing-customer-service-new/
#   ✔ WriteX - Email Writing (Customer Service) (New) - Types: P, A, K, S, B
#
# [373/377] Visiting: https://www.shl.com/products/product-catalog/view/writex-email-writing-managerial-new/
#   ✔ WriteX - Email Writing (Managerial) (New) - Types: P, A, K, S, B
#
# [374/377] Visiting: https://www.shl.com/products/product-catalog/view/writex-email-writing-sales-new/
#   ✔ WriteX - Email Writing (Sales) (New) - Types: P, A, K, S, B
#
# [375/377] Visiting: https://www.shl.com/products/product-catalog/view/written-english-v1/
#   ✔ Written English v1 - Types: P, A, K, S, B
#
# [376/377] Visiting: https://www.shl.com/products/product-catalog/view/written-spanish/
#   ✔ Written Spanish - Types: P, A, K, S, B
#
# [377/377] Visiting: https://www.shl.com/products/product-catalog/view/zabbix-new/
#   ✔ Zabbix (New) - Types: P, A, K, S, B
#
# ============================================================
# FINAL RESULTS
# ============================================================
# Total Individual Test Solutions scraped: 377
#
# ✓ Saved → data/raw/shl_catalog.csv
