# %% [markdown]
# (venv) C:\Users\hbish\Desktop\Shl Recommendation System>python src/recommendation/embedder.py
# Loading data from: data/raw/shl_catalog.csv
# Loaded 377 assessments
# Loading embedding model: all-MiniLM-L6-v2
#
# Generating embeddings...
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████| 12/12 [00:03<00:00,  3.93it/s]
# ✓ Generated 377 embeddings
#   Embedding dimension: 384
#
# ✓ Saved embeddings to: data\processed\embeddings.npy
# ✓ Saved metadata to: data\processed\metadata.csv
#
# ======================================================================
# EMBEDDING GENERATION COMPLETE
# ======================================================================
